# %%
# %matplotlib inline
from query.datasets.prelude import *
import pysrt
import textacy
import gensim
# Out:
# DEBUG 2017-12-08 15:24:46,193 doc2vec.py:073] Fast version of gensim.models.doc2vec is being used
# INFO 2017-12-08 15:24:46,203 textcleaner.py:020] 'pattern' package not found; tag filters are not available for English

# %%
# Load transcripts and compute time offsets for captions
transcripts = []
for video in Video.objects.exclude(path__contains='segment'):
    base = os.path.split(os.path.splitext(video.path)[0])[1]
    subs = pysrt.open('/app/subs/{}.cc5.srt'.format(base))
    offsets = []
    transcript = ''
    for sub in subs:
        offsets.append((len(transcript), sub.start, sub.end))
        transcript += sub.text.replace('\n', ' ').replace('>', ' ') + ' '
    transcripts.append((video, transcript, offsets))

# %%
# Convert transcripts into textacy Docs (implicitly performing various NLP tasks)
docs = [textacy.doc.Doc(transcript, lang=u'en', metadata={'path': video.path, 'offsets': offsets}) for (video, transcript, offsets) in transcripts]
corpus = textacy.Corpus(u'en', docs=docs)
# Out:
# DEBUG 2017-12-08 15:24:56,616 cache.py:088] Loading "en" spaCy pipeline

# %%
# Helper functions
def token_time(doc, tok):
    tok_offset = tok.idx
    for i, (offset, start, end) in enumerate(doc.metadata['offsets']):
        if tok_offset < offset:
            return (start, end)
    raise Exception("No token time?")
    
def compute_tfidf(corpus):
    gensim_dict = gensim.corpora.Dictionary(corpus)
    gensim_corpus = [gensim_dict.doc2bow(text) for text in transcript_words]
    tfidf_model = gensim.models.tfidfmodel.TfidfModel(gensim_corpus, normalize=True)
    return {gensim_dict.get(id): value for doc in tfidf[gensim_corpus] for id, value in doc}

# %%
# Load Word2Vec model
model = gensim.models.KeyedVectors.load_word2vec_format('/app/deps/word2vec/GoogleNews-vectors-negative300.bin', binary=True)

def sim_score(a, b):
    try:
        return model.wv.similarity(a, b)
    except KeyError:
        return 0
# Out:
# INFO 2017-12-08 15:28:06,556 keyedvectors.py:201] loading projection weights from /app/deps/word2vec/GoogleNews-vectors-negative300.bin
# DEBUG 2017-12-08 15:28:06,557 smart_open_lib.py:149] {'kw': {}, 'mode': 'rb', 'uri': '/app/deps/word2vec/GoogleNews-vectors-negative300.bin'}
# DEBUG 2017-12-08 15:28:06,578 smart_open_lib.py:621] encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/app/deps/word2vec/GoogleNews-vectors-negative300.bin', mode 'rb' at 0x7f0a01b76150>, 'encoding': None}
# INFO 2017-12-08 15:29:04,257 keyedvectors.py:263] loaded (3000000, 300) matrix from /app/deps/word2vec/GoogleNews-vectors-negative300.bin

# %%
model.wv.similarity('economy', 'jobs')
# Out:
# 0.40456532973171394

# %%
# TODO: incorporate TFIDF segments

topics = ['immigration', 'china', 'syria', 'terrorism', 'economy', 'election']
transcript_tokens = [
    list(textacy.extract.words(doc, filter_nums=True, include_pos=['PROPN', 'NOUN'])) 
    for doc in corpus.docs]
  
N = len(topics)    
#fig, ax = plt.subplots(2, N / 2, figsize=(18, 16))
#ax = ax.flatten()
W = 30
MENTION_THRESHOLD = 3
PEAK_DURATION_THRESHOLD = 5

def topic_peaks(topic, tokens):
    scores = np.array([sim_score(token.text.lower(), topic) for token in tokens])
    scores = scores > 0.6
    sums = np.array([np.sum(scores[j:j+W]) for j in range(W, len(scores) - W)]) >= MENTION_THRESHOLD
    start = None
    peaks = []
    for j in range(len(sums)):
        if sums[j] and start is None:
            start = j
        elif not sums[j] and start is not None:
            idx = (start + j) / 2 + W
            peak_duration = j - start
            if peak_duration > PEAK_DURATION_THRESHOLD:
                peaks.append((tokens[idx], peak_duration))
            start = None

    #ax[i].set_ylim([0, 1])
    #ax[i].set_title(topic)
    #ax[i].plot(sums)
    
    return peaks


topic_labeler, _ = Labeler.objects.get_or_create(name='word2vec')
topic_tracks = []
for tokens, doc in zip(transcript_tokens, corpus.docs):
    print(doc.metadata['path'])
    video = Video.objects.get(path=doc.metadata['path'])
    for i, topic in enumerate(topics): 
        peaks = topic_peaks(topic, tokens)
        print(topic, peaks)
        for (token, _) in peaks:
            (start, end) = token_time(doc, token)
            start = start.to_time()
            seconds = (((start.hour * 60) + start.minute) * 60 + start.second)
            
            # Naively assume 4 minute segment size
            min_time = max(seconds - 2 * 60, 0)
            max_time = min(seconds + 2 * 60, int(video.num_frames / video.fps))
            
            topic_model, _ = Topic.objects.get_or_create(name=topic)
            track = TopicTrack(
                video=video, min_frame=min_time*video.fps, max_frame=max_time*video.fps, topic=topic_model,
                labeler=topic_labeler)
            topic_tracks.append(track)
#_ = TopicTrack.objects.bulk_create(topic_tracks)
# Out:
# tvnews/videos/CNN_20120429_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [(UNITED, 30)])
# ('china', [(DETAINED, 14), (DICTATORSHIP, 23)])
# ('syria', [(SECURITY, 25)])
# ('terrorism', [])
# ('economy', [(BUDGET, 30)])
# ('election', [])
# tvnews/videos/CNN_20121102_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(VIEW, 30)])
# ('terrorism', [])
# ('economy', [(UNEMPLOYMENT, 27)])
# ('election', [(PRESIDENT, 30), (WORRIES, 14), (DAY, 25), (SMALL, 18), (JOBS, 10)])
# tvnews/videos/CNNW_20120809_200000_The_Situation_Room.mp4
# ('immigration', [(PROGRAMS, 20)])
# ('china', [])
# ('syria', [(LEE, 15), (FIGHT, 6), (SERIOUS, 29)])
# ('terrorism', [])
# ('economy', [(PRESIDENT, 24)])
# ('election', [(OBAMA, 9), (JOURNAL, 9)])
# tvnews/videos/FOXNEWSW_20160401_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(ISIS, 8)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(CAMPAIGN, 8)])
# tvnews/videos/FOXNEWSW_20120421_200000_Americas_News_Headquarters.mp4
# ('immigration', [(IT, 8), (AMERICAN, 11), (Heather, 11), (VOTERS, 6)])
# ('china', [])
# ('syria', [(TIME, 8), (GROUP, 32), (REASONING, 6)])
# ('terrorism', [])
# ('economy', [(FORWARD, 12), (INTERRELATED, 6)])
# ('election', [(SEVEN, 7), (STEGALL, 21), (WHAT, 17), (GOVERNOR, 8)])
# tvnews/videos/FOXNEWSW_20160830_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [(CORE, 14), (IT, 6), (DETAILS, 12)])
# ('china', [])
# ('syria', [(CAM, 23)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(DONALD, 13), (FBI, 7), (FLORIDA, 6)])
# tvnews/videos/FOXNEWSW_20160929_230000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(SENSE, 8), (SECURITY, 16)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(SHORE, 6), (LUMP, 17)])
# tvnews/videos/CNNW_20160813_200000_CNN_Newsroom_With_Poppy_Harlow.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(WOMEN, 29), (HAD, 31), (BANKRUPTCY, 31), (FLORIDA, 9)])
# tvnews/videos/FOXNEWSW_20120907_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(RIGHT, 30)])
# tvnews/videos/CNN_20120201_160000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(PEOPLE, 6), (BOARD, 11)])
# tvnews/videos/CNN_20120205_180000_Fareed_Zakaria_GPS.mp4
# ('immigration', [])
# ('china', [(REAL, 24), (AREAS, 25)])
# ('syria', [(STOP, 7)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(PUTINISH, 12)])
# tvnews/videos/CNN_20120318_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [])
# ('china', [(PRESSURE, 30), (WEAPONS, 16)])
# ('syria', [(NUCLEAR, 16)])
# ('terrorism', [])
# ('economy', [(GOT, 18)])
# ('election', [])
# tvnews/videos/CNN_20120327_190000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNN_20120428_200000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNN_20120602_220000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [(PRESIDENT, 10)])
# ('election', [])
# tvnews/videos/CNN_20120610_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [(GLOBAL, 25)])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(OLD, 23), (EVERYBODY, 37), (OUTSIDE, 15)])
# tvnews/videos/CNN_20120620_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(ATTACK, 32), (Decision, 13), (ESPIONAGE, 12), (TALK, 22), (IRANIAN, 47)])
# ('terrorism', [])
# ('economy', [(SHALL, 22)])
# ('election', [(DELAYED, 17)])
# tvnews/videos/CNN_20120722_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(ABLE, 30)])
# tvnews/videos/CNN_20120724_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(CUTS, 21), (AGAINST, 15), (IRAQ, 21), (EVERYTHING, 31), (WHAT, 27), (STRATEGY, 23), (NEARLY, 22), (ENGLAND, 6), (SHABBY, 14), (INFORMATION, 8), (SOUTHERN, 68), (SECRETARY, 55), (SECRETARY, 6), (CASE, 33), (PRESIDENCY, 22), (SECONDLY, 7)])
# ('terrorism', [])
# ('economy', [(FILE, 12), (CANDIDATE, 6), (FILE, 30)])
# ('election', [(SUPPORT, 20)])
# tvnews/videos/CNN_20120825_190000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNN_20120827_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(JOHNSON, 6), (SUMMIT, 19)])
# ('terrorism', [])
# ('economy', [(COUNTRY, 23)])
# ('election', [(IT, 24), (IT, 7)])
# tvnews/videos/CNN_20120902_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [])
# ('china', [(NATIONS, 11), (YEAR, 13)])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(THEY'RE, 30)])
# tvnews/videos/CNN_20120919_170000_CNN_Newsroom.mp4
# ('immigration', [(MEMBERS, 13)])
# ('china', [])
# ('syria', [(WHAT, 7), (MINING, 21)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(MITT, 7), (GROUND, 26)])
# tvnews/videos/CNN_20120929_220000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(FURIOUS, 7)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(ROMNEY, 23)])
# tvnews/videos/CNN_20121014_170000_Fareed_Zakaria_GPS.mp4
# ('immigration', [])
# ('china', [(SIDES, 20)])
# ('syria', [(END, 6)])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNN_20121021_210000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(STATES, 21), (ALLIES, 16), (YORK, 30)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(UNIVERSITY, 13)])
# tvnews/videos/CNNW_20120227_180000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(COURSE, 19), (LAW, 8)])
# tvnews/videos/CNNW_20120529_170000_CNN_Newsroom.mp4
# ('immigration', [(ECONOMY, 30)])
# ('china', [])
# ('syria', [(COUNTRIES, 26)])
# ('terrorism', [])
# ('economy', [(EVERYONE, 14)])
# ('election', [])
# tvnews/videos/CNNW_20120630_190000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(Farmers, 19)])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNNW_20120706_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [(WORDS, 7), (CONFERENCE, 19), (URGENTLY, 6)])
# ('syria', [(POWER, 14), (ULTIMATE, 30)])
# ('terrorism', [])
# ('economy', [(MOST, 8)])
# ('election', [(BEEN, 18), (JOB, 22)])
# tvnews/videos/CNNW_20120730_170000_CNN_Newsroom.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(DECISION, 24), (ISRAEL, 30), (TEL, 13), (LARGEST, 22), (ATTACK, 6), (VETERAN, 42)])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/CNNW_20121016_200000_The_Situation_Room.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [(MITT, 20), (DISPUTE, 21)])
# ('economy', [(ROMNEY, 8)])
# ('election', [(BATTLEGROUND, 34), (COURT, 15), (WHO, 10), (PEOPLE, 18), (HIM, 23)])
# tvnews/videos/FOXNEWSW_20160418_180000_The_Real_Story_With_Gretchen_Carlson.mp4
# ('immigration', [(TEST, 21)])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(MAJORITY, 30), (SOMETHING, 13)])
# tvnews/videos/FOXNEWSW_20160503_180000_The_Real_Story_With_Gretchen_Carlson.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(LOSING, 7), (DIFFERENCE, 29)])
# tvnews/videos/CNNW_20121125_180000_Fareed_Zakaria_GPS.mp4
# ('immigration', [(TIME, 16), (NEWS, 7)])
# ('china', [])
# ('syria', [(INTERESTS, 66), (STRATEGY, 6), (CERTAIN, 32), (SAUDI, 6)])
# ('terrorism', [(COUNTERWEIGHT, 20)])
# ('economy', [])
# ('election', [(MENTION, 29)])
# tvnews/videos/FOXNEWSW_20160503_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(THEY'RE, 24), (SENTIMENT, 12), (TRUMP, 17)])
# tvnews/videos/CNNW_20160201_210000_The_Lead_With_Jake_Tapper.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(VERY, 28)])
# tvnews/videos/FOXNEWSW_20160518_180000_The_Real_Story_With_Gretchen_Carlson.mp4
# ('immigration', [])
# ('china', [(UN, 18)])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20120825_160000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(LEADER, 29)])
# tvnews/videos/FOXNEWSW_20160527_210000_The_Five.mp4
# ('immigration', [])
# ('china', [(WHO, 30)])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20120623_170000_Americas_News_Headquarters.mp4
# ('immigration', [(FACT, 9), (ECONOMY, 21)])
# ('china', [])
# ('syria', [(YESTERDAY, 23), (MUJAHEDDIN, 6), (POWERS, 37)])
# ('terrorism', [])
# ('economy', [(WE'VE, 30)])
# ('election', [])
# tvnews/videos/FOXNEWSW_20160601_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [(PLACE, 19)])
# ('election', [(B, 20)])
# tvnews/videos/FOXNEWSW_20160603_180000_The_Real_Story_With_Gretchen_Carlson.mp4
# ('immigration', [(POLL, 7), (PREVIOUS, 9), (ISSUE, 19)])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [(GDP, 28), (JOBS, 13)])
# ('election', [])
# tvnews/videos/FOXNEWSW_20120312_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [(WEALTHY, 30)])
# ('election', [(MAJOR, 6), (DONATION, 25)])
# tvnews/videos/FOXNEWSW_20160620_180000_The_Real_Story_With_Gretchen_Carlson.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [(SALES, 9), (BUY, 30)])
# ('economy', [])
# ('election', [(TRUMP, 28), (TEMPS, 21)])
# tvnews/videos/FOXNEWSW_20120226_200000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWS_20121025_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(IDEA, 46)])
# tvnews/videos/FOXNEWSW_20160701_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [(DEATH, 20), (PRIME, 16), (PROFESSOR, 13)])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWS_20120922_200000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(PROTESTORS, 20), (ISRAEL, 67)])
# ('terrorism', [])
# ('economy', [(PERCENT, 15)])
# ('election', [(APPLAUSE, 19)])
# tvnews/videos/FOXNEWSW_20160801_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(HILLARY, 9), (TODAY, 30)])
# tvnews/videos/FOXNEWS_20120724_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20160829_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWS_20120722_160000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(BOMBING, 10), (MINISTER, 17), (THREAT, 6), (BOMBING, 15), (SHANNON, 13), (STATES, 30), (CONCERN, 25)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(SCANDAL, 29), (WHOOF, 14)])
# tvnews/videos/FOXNEWS_20120604_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [(CONDITION, 6)])
# ('election', [(AWARDS, 25)])
# tvnews/videos/FOXNEWS_20120520_160000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [(FAMILY, 24)])
# ('syria', [(TALKS, 9)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(JOHN, 16), (PEOPLE, 8), (WONDER, 30), (PARK, 27)])
# tvnews/videos/FOXNEWSW_20160908_230000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(goodnight, 29)])
# tvnews/videos/FOXNEWS_20120420_210000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20160913_235000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20160919_230000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [(FORCE, 30), (ENEMY, 17), (TIME, 28)])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWS_20120325_160000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [])
# tvnews/videos/FOXNEWSW_20160923_230000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(POINTS, 32), (NATIONAL, 12), (ROMNEY, 9)])
# tvnews/videos/FOXNEWS_20120204_170000_Americas_News_Headquarters.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [(ASSAD, 22), (MARK, 23)])
# ('terrorism', [])
# ('economy', [])
# ('election', [(DELEGATES, 11), (PAUL, 22)])
# tvnews/videos/FOXNEWSW_20160928_190000_Shepard_Smith_Reporting.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(FAMILIES, 12), (VULNERABLE, 17), (UNITY, 30), (BATTLEGROUND, 30)])
# tvnews/videos/FOXNEWS_20120201_220000_The_Five.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(IT, 8)])
# tvnews/videos/CNNW_20161101_200000_The_Lead_With_Jake_Tapper.mp4
# ('immigration', [])
# ('china', [])
# ('syria', [])
# ('terrorism', [])
# ('economy', [])
# ('election', [(GROUND, 27), (HAD, 30), (WHO, 30), (ANYTHING, 16)])
# tvnews/videos/FOXNEWSW_20161005_230000_On_the_Record_With_Brit_Hume.mp4
# ('immigration', [(TREAT, 30)])
# ('china', [])
# ('syria', [(NIGHT, 16)])
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-ed81fc9162ad> in <module>()
#      40     video = Video.objects.get(path=doc.metadata['path'])
#      41     for i, topic in enumerate(topics):
# ---> 42         peaks = topic_peaks(topic, tokens)
#      43         print(topic, peaks)
#      44         for (token, _) in peaks:
#
# <ipython-input-6-ed81fc9162ad> in topic_peaks(topic, tokens)
#      12
#      13 def topic_peaks(topic, tokens):
# ---> 14     scores = np.array([sim_score(token.text.lower(), topic) for token in tokens])
#      15     scores = scores > 0.6
#      16     sums = np.array([np.sum(scores[j:j+W]) for j in range(W, len(scores) - W)]) >= MENTION_THRESHOLD
#
# <ipython-input-5-fd550b45cd17> in sim_score(a, b)
#       4 def sim_score(a, b):
#       5     try:
# ----> 6         return model.wv.similarity(a, b)
#       7     except KeyError:
#       8         return 0
#
# KeyboardInterrupt:
